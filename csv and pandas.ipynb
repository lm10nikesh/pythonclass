# %%
import pandas as pd
df = pd.read_csv('Salary Data.csv')            #df=dataframe
df
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# ...

# %%
df = pd.read_csv('Salary Data.csv', nrows= 5)         
df
# Out:
#    Age  Gender Education Level          Job Title  Years of Experience  Salary
# 0   32    Male      Bachelor's  Software Engineer                    5   90000
# 1   28  Female        Master's       Data Analyst                    3   65000
# 2   45    Male             PhD     Senior Manager                   15  150000
# 3   36  Female      Bachelor's    Sales Associate                    7   60000
# 4   52    Male        Master's           Director                   20  200000

# %%
df = pd.read_csv('Salary Data.csv')            
df.head()                           #5 samples from the top
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
df = pd.read_csv('Salary Data.csv')            
df.tail()                           #5 samples from the bottom
# Out:
#       Age  Gender Education Level                      Job Title  \
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 370                  8.0   85000.0
# 371                 19.0  170000.0
# 372                  2.0   40000.0
# 373                  7.0   90000.0
# 374                 15.0  150000.0

# %%
df = pd.read_csv('Salary Data.csv', 
                 usecols= ['Age','Gender']) 
df
# Out:
#       Age  Gender
# 0    32.0    Male
# 1    28.0  Female
# 2    45.0    Male
# 3    36.0  Female
# 4    52.0    Male
# ..    ...     ...
# 370  35.0  Female
# 371  43.0    Male
# 372  29.0  Female
# 373  34.0    Male
# 374  44.0  Female
#
# [375 rows x 2 columns]

# %%
df = pd.read_csv('Salary Data.csv', 
                 usecols= ['Years of Experience','Salary']) 
df.head(10)
# Out:
#    Years of Experience    Salary
# 0                  5.0   90000.0
# 1                  3.0   65000.0
# 2                 15.0  150000.0
# 3                  7.0   60000.0
# 4                 20.0  200000.0
# 5                  2.0   55000.0
# 6                 12.0  120000.0
# 7                  4.0   80000.0
# 8                  1.0   45000.0
# 9                 10.0  110000.0

# %%
df = pd.read_csv('Salary Data.csv')                    
data=df[['Education Level','Years of Experience','Salary']]       #alternate way to select specific columns   
data
# Out:
#     Education Level  Years of Experience    Salary
# 0        Bachelor's                  5.0   90000.0
# 1          Master's                  3.0   65000.0
# 2               PhD                 15.0  150000.0
# 3        Bachelor's                  7.0   60000.0
# 4          Master's                 20.0  200000.0
# ..              ...                  ...       ...
# 370      Bachelor's                  8.0   85000.0
# 371        Master's                 19.0  170000.0
# 372      Bachelor's                  2.0   40000.0
# 373      Bachelor's                  7.0   90000.0
# 374             PhD                 15.0  150000.0
#
# [375 rows x 3 columns]

# %%
#iloc loc           index localizer
 
df = pd.read_csv('Salary Data.csv') 
df.iloc[10:25]
# Out:
#      Age  Gender Education Level             Job Title  Years of Experience  \
# 10  29.0    Male        Master's    Software Developer                  3.0
# 11  48.0  Female      Bachelor's            HR Manager                 18.0
# 12  35.0    Male      Bachelor's     Financial Analyst                  6.0
# 13  40.0  Female        Master's       Project Manager                 14.0
# 14  27.0    Male      Bachelor's  Customer Service Rep                  2.0
# 15  44.0    Male      Bachelor's    Operations Manager                 16.0
# 16  33.0  Female        Master's     Marketing Manager                  7.0
# 17  39.0    Male             PhD       Senior Engineer                 12.0
# 18  25.0  Female      Bachelor's      Data Entry Clerk                  0.0
# 19  51.0    Male      Bachelor's        Sales Director                 22.0
# 20  34.0  Female        Master's      Business Analyst                  5.0
# ...

# %%
df = pd.read_csv('Salary Data.csv', 
                 usecols= ['Years of Experience','Salary']) 
df.iloc[5:16]
# Out:
#     Years of Experience    Salary
# 5                   2.0   55000.0
# 6                  12.0  120000.0
# 7                   4.0   80000.0
# 8                   1.0   45000.0
# 9                  10.0  110000.0
# 10                  3.0   75000.0
# 11                 18.0  140000.0
# 12                  6.0   65000.0
# 13                 14.0  130000.0
# 14                  2.0   40000.0
# 15                 16.0  125000.0

# %%
df.iloc[5:16,0:3]
# Out:
#     Years of Experience    Salary
# 5                   2.0   55000.0
# 6                  12.0  120000.0
# 7                   4.0   80000.0
# 8                   1.0   45000.0
# 9                  10.0  110000.0
# 10                  3.0   75000.0
# 11                 18.0  140000.0
# 12                  6.0   65000.0
# 13                 14.0  130000.0
# 14                  2.0   40000.0
# 15                 16.0  125000.0

# %%
df = pd.read_csv('Salary Data.csv')            
df[(df['Gender'] == 'Female') & (df["Age"]>40)]
# Out:
#       Age  Gender Education Level                 Job Title  \
# 6    42.0  Female        Master's           Product Manager
# 11   48.0  Female      Bachelor's                HR Manager
# 28   43.0  Female             PhD         Senior Consultant
# 47   45.0  Female        Master's     Director of Marketing
# 50   51.0  Female      Bachelor's  Customer Service Manager
# ..    ...     ...             ...                       ...
# 350  44.0  Female             PhD     Senior Data Scientist
# 356  45.0  Female             PhD        Senior UX Designer
# 362  44.0  Female             PhD   Senior Business Analyst
# 368  44.0  Female             PhD      Senior Data Engineer
# 374  44.0  Female             PhD   Senior Business Analyst
#
#      Years of Experience    Salary
# 6                   12.0  120000.0
# 11                  18.0  140000.0
# 28                  15.0  140000.0
# 47                  16.0  180000.0
# 50                  22.0  130000.0
# ...

# %%
df['Gender']
# Out:
# 0        Male
# 1      Female
# 2        Male
# 3      Female
# 4        Male
#         ...
# 370    Female
# 371      Male
# 372    Female
# 373      Male
# 374    Female
# Name: Gender, Length: 375, dtype: object

# %%
df[['Gender']]
# Out:
#      Gender
# 0      Male
# 1    Female
# 2      Male
# 3    Female
# 4      Male
# ..      ...
# 370  Female
# 371    Male
# 372  Female
# 373    Male
# 374  Female
#
# [375 rows x 1 columns]

# %%
df[df['Gender'] == 'Male'].count()
# Out:
# Age                    194
# Gender                 194
# Education Level        194
# Job Title              194
# Years of Experience    194
# Salary                 194
# dtype: int64

# %%
len(df[df['Gender'] == 'Male'])
# Out:
# 194

# %%
df[df['Salary'] >= 50000]
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 369  33.0    Male      Bachelor's        Junior Business Analyst
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# ...

# %%
df[(df['Salary'] >= 50000) & (df['Gender'] == 'Female')]
# Out:
#       Age  Gender Education Level                 Job Title  \
# 1    28.0  Female        Master's              Data Analyst
# 3    36.0  Female      Bachelor's           Sales Associate
# 6    42.0  Female        Master's           Product Manager
# 11   48.0  Female      Bachelor's                HR Manager
# 13   40.0  Female        Master's           Project Manager
# ..    ...     ...             ...                       ...
# 364  35.0  Female      Bachelor's  Senior Financial Manager
# 366  31.0  Female      Bachelor's  Junior Financial Analyst
# 368  44.0  Female             PhD      Senior Data Engineer
# 370  35.0  Female      Bachelor's  Senior Marketing Analyst
# 374  44.0  Female             PhD   Senior Business Analyst
#
#      Years of Experience    Salary
# 1                    3.0   65000.0
# 3                    7.0   60000.0
# 6                   12.0  120000.0
# 11                  18.0  140000.0
# 13                  14.0  130000.0
# ...

# %%
data = df[(df['Salary'] >= 50000) & (df['Gender'] == 'Female')]
data.to_csv('Female_50.csv')
data
# Out:
#       Age  Gender Education Level                 Job Title  \
# 1    28.0  Female        Master's              Data Analyst
# 3    36.0  Female      Bachelor's           Sales Associate
# 6    42.0  Female        Master's           Product Manager
# 11   48.0  Female      Bachelor's                HR Manager
# 13   40.0  Female        Master's           Project Manager
# ..    ...     ...             ...                       ...
# 364  35.0  Female      Bachelor's  Senior Financial Manager
# 366  31.0  Female      Bachelor's  Junior Financial Analyst
# 368  44.0  Female             PhD      Senior Data Engineer
# 370  35.0  Female      Bachelor's  Senior Marketing Analyst
# 374  44.0  Female             PhD   Senior Business Analyst
#
#      Years of Experience    Salary
# 1                    3.0   65000.0
# 3                    7.0   60000.0
# 6                   12.0  120000.0
# 11                  18.0  140000.0
# 13                  14.0  130000.0
# ...

# %%
df.describe()
# Out:
#               Age  Years of Experience         Salary
# count  373.000000           373.000000     373.000000
# mean    37.431635            10.030831  100577.345845
# std      7.069073             6.557007   48240.013482
# min     23.000000             0.000000     350.000000
# 25%     31.000000             4.000000   55000.000000
# 50%     36.000000             9.000000   95000.000000
# 75%     44.000000            15.000000  140000.000000
# max     53.000000            25.000000  250000.000000

# %%
data = {'name':['Ram','Shyam','Hari'],
       'age':[34,36,41],
       'add':['Kathmandu','Pokhara','Lalitpur']}
df = pd.DataFrame(data)
df.to_csv('info.csv')
df
# Out:
#     name  age        add
# 0    Ram   34  Kathmandu
# 1  Shyam   36    Pokhara
# 2   Hari   41   Lalitpur

# %%
import pandas as pd

df = pd.DataFrame({'Names':['Ram', 'Shyam', 'Hari','Bikash', 'Samrat'],

'Address':['Kathmandu','Palpa','Pyuthan','Bhaktapur','Patan'],

'Age':[21, 22, 20, 19, 18]})

df.to_csv('boooks.csv')

df
# Out:
#     Names    Address  Age
# 0     Ram  Kathmandu   21
# 1   Shyam      Palpa   22
# 2    Hari    Pyuthan   20
# 3  Bikash  Bhaktapur   19
# 4  Samrat      Patan   18

# %%
import csv
data = [['name','age','add'],                  #list inside list
       ['Ram','16','Kathmandu'],
       ['Hari','28','Pokhara'],
       ['Sita','24','Bhaktapur']]

file=open('list_data.csv','w')
x = csv.writer(file)
x.writerows(data)
file.close()

# %%
import pandas as pd
df = pd.read_csv('list_data.csv')
df
# Out:
#    name  age        add
# 0   Ram   16  Kathmandu
# 1  Hari   28    Pokhara
# 2  Sita   24  Bhaktapur

# %%
import csv

with open('list_data.csv') as csvfile:

    reader = csv.DictReader(csvfile)

    for row in reader:

        print(row)
# Out:
# {'name': 'Ram', 'age': '16', 'add': 'Kathmandu'}
# {'name': 'Hari', 'age': '28', 'add': 'Pokhara'}
# {'name': 'Sita', 'age': '24', 'add': 'Bhaktapur'}

# %%
data = [
{'name': 'Ram', 'age': '16', 'add': 'Kathmandu'},
{'name': 'Hari', 'age': '28', 'add': 'Pokhara'},
{'name': 'Sita', 'age': '24', 'add': 'Bhaktapur'}
]
data
# Out:
# [{'name': 'Ram', 'age': '16', 'add': 'Kathmandu'},
#  {'name': 'Hari', 'age': '28', 'add': 'Pokhara'},
#  {'name': 'Sita', 'age': '24', 'add': 'Bhaktapur'}]

# %%
import csv

csv_columns = ['name', 'age', 'add']

dict = [
   {'name': 'Ram', 'age': '16', 'add': 'Kathmandu'},
   {'name': 'Hari', 'age': '28', 'add': 'Pokhara'},
   {'name': 'Sita', 'age': '24', 'add': 'Bhaktapur'}
   ]

with open("data.csv", 'w') as csvfile:

    writer = csv.DictWriter(csvfile, fieldnames=csv_columns)

    writer.writeheader()

    writer.writerows(data)

# %%
import pandas as pd
df= pd.read_csv("data.csv")
df
# Out:
#    name  age        add
# 0   Ram   16  Kathmandu
# 1  Hari   28    Pokhara
# 2  Sita   24  Bhaktapur

# %%
df1= pd.DataFrame({
    'name':['Ram','Shyam'],
    'age':[23,26],
    'add':['ktm','pkr']
})

df2= pd.DataFrame({
    'name':['Rama','Shyama'],
    'age':[25,29],
    'add':['Bgl','Jhapa']
})

#df = df1 + df2                     this is wrong method to concat here
df = pd.concat([df1,df2])
df
# Out:
#      name  age    add
# 0     Ram   23    ktm
# 1   Shyam   26    pkr
# 0    Rama   25    Bgl
# 1  Shyama   29  Jhapa
